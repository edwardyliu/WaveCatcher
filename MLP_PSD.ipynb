# %%
"""
    Get cleaned data
"""

import numpy as np

dataset = np.load('./datasets/PSD_per_Hz.npy')
labels = np.load('./datasets/labels.npy')

# %%
"""
    Split dataset
"""

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

flatten_dataset = dataset.reshape(dataset.shape[0], -1)
shuf_dataset, shuf_labels = shuffle(flatten_dataset, labels)
X_train, X_test, y_train, y_test = train_test_split(shuf_dataset, shuf_labels, test_size=0.2)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)
print("Train set size: {}, Val set size: {}, Test set size: {}".format(len(X_train), len(X_val), len(X_test)))
print(y_train.shape)
print(X_train.shape)
# Out:
# Train set size: 711, Val set size: 89, Test set size: 89
# (711,)
# (711, 196)

# %%
"""
    Model and train
"""

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import ModelCheckpoint

model_path = './models/'
json_name = 'MLP_PSD.json'
weight_name = 'MLP_PSD.h5'

batch_size = 64
epochs = 128
num_classes = 2
input_dim = X_train.shape[1]

print("Constructing MLP Model: ...", end='')
model = Sequential()
# Input
model.add(Dense(36, input_dim=input_dim, activation='relu'))

# Hidden
model.add(Dropout(0.3, noise_shape=None, seed=None))
model.add(Dense(36, activation='relu'))
model.add(Dropout(0.2, noise_shape=None, seed=None))
model.add(Dense(24, activation='relu'))
model.add(Dropout(0.1, noise_shape=None, seed=None))
model.add(Dense(12, activation='relu'))

# Classification
model.add(Dense(1, activation='sigmoid'))
print(" Complete.")
model.summary()

print("Compiling MLP Model: ...", end='')
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
print(" Complete.")

mcp_save = ModelCheckpoint(filepath=model_path+weight_name, save_best_only=True, monitor='val_loss', mode='min')

print("Fitting MLP Model: ...")
results = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[mcp_save], validation_data=(X_val, y_val))
print("Complete.")
# Out:
# Constructing MLP Model: ... Complete.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 36)                7092
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 36)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 36)                1332
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 36)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 24)                888
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 12)                300
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 13
# =================================================================
# Total params: 9,625
# Trainable params: 9,625
# Non-trainable params: 0
# _________________________________________________________________
# Compiling MLP Model: ... Complete.
# Fitting MLP Model: ...
# Train on 711 samples, validate on 89 samples
# Epoch 1/128
# 711/711 [==============================] - 1s 1ms/step - loss: 1.0167 - acc: 0.5063 - val_loss: 0.5031 - val_acc: 0.7416
# Epoch 2/128
# 711/711 [==============================] - 0s 41us/step - loss: 0.5999 - acc: 0.6920 - val_loss: 0.4512 - val_acc: 0.7865
# Epoch 3/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.5538 - acc: 0.7187 - val_loss: 0.4042 - val_acc: 0.8202
# Epoch 4/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.5228 - acc: 0.7454 - val_loss: 0.3891 - val_acc: 0.8202
# Epoch 5/128
# 711/711 [==============================] - 0s 45us/step - loss: 0.5081 - acc: 0.7342 - val_loss: 0.3811 - val_acc: 0.8202
# Epoch 6/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.4843 - acc: 0.7722 - val_loss: 0.3654 - val_acc: 0.8315
# Epoch 7/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.4674 - acc: 0.7722 - val_loss: 0.3874 - val_acc: 0.8315
# Epoch 8/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.4543 - acc: 0.7750 - val_loss: 0.3507 - val_acc: 0.8427
# Epoch 9/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.4179 - acc: 0.8045 - val_loss: 0.3307 - val_acc: 0.8427
# Epoch 10/128
# 711/711 [==============================] - 0s 44us/step - loss: 0
128
# 711/711 [==============================] - 0s 42us/step - loss: 0.0694 - acc: 0.9747 - val_loss: 0.1415 - val_acc: 0.9326
# Epoch 121/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.0731 - acc: 0.9691 - val_loss: 0.1566 - val_acc: 0.9326
# Epoch 122/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.0773 - acc: 0.9662 - val_loss: 0.1348 - val_acc: 0.9551
# Epoch 123/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.0803 - acc: 0.9508 - val_loss: 0.1267 - val_acc: 0.9326
# Epoch 124/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.0655 - acc: 0.9662 - val_loss: 0.1502 - val_acc: 0.9101
# Epoch 125/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.0917 - acc: 0.9578 - val_loss: 0.1644 - val_acc: 0.8989
# Epoch 126/128
# 711/711 [==============================] - 0s 41us/step - loss: 0.0851 - acc: 0.9677 - val_loss: 0.1433 - val_acc: 0.9213
# Epoch 127/128
# 711/711 [==============================] - 0s 42us/step - loss: 0.0727 - acc: 0.9691 - val_loss: 0.2000 - val_acc: 0.9213
# Epoch 128/128
# 711/711 [==============================] - 0s 44us/step - loss: 0.0714 - acc: 0.9634 - val_loss: 0.1708 - val_acc: 0.9438
# Complete.

# %%
"""
    Save the model
"""

model_path = './models/'
json_name = 'MLP_PSD.json'
weight_name = 'MLP_PSD.h5'

model_json = model.to_json()
with open(model_path+json_name, 'w') as json_file:
    json_file.write(model_json)
model.save_weights(model_path+weight_name)

# %%
"""
    Output & plot the results
    Aspect Ratio 2 to 1
"""

import matplotlib.pyplot as plt

image_path = './graphs/'
image_name = 'MLP_PSD_2to1.png'

fig = plt.figure(figsize=(10,5))
plt.plot(results.history['loss'], label='train loss')
plt.plot(results.history['val_loss'], label='val loss')
plt.plot(results.history['acc'], label='train acc')
plt.plot(results.history['val_acc'], label='val acc')
plt.legend(loc='lower left')
plt.title('Power Spectral Density [1-50 Hz] MLP')
plt.xlabel('Epoch(s)')
plt.ylabel('Performance')
#plt.show()
plt.savefig(image_path+image_name, bbox_inches='tight')
test_scores = model.evaluate(X_test, y_test)
print("\nFinal test %s: %.2f%%" % (model.metrics_names[1], test_scores[1]*100))
# Out:
# 89/89 [==============================] - 0s 34us/step
#
# Final test acc: 91.01%

# %%
"""
    Output & plot the results
    Aspect Ratio 2 to 1
"""

import matplotlib.pyplot as plt

image_path = './graphs/'
image_name = 'MLP_PSD_16to9.png'

fig = plt.figure(figsize=(16,9))
plt.plot(results.history['loss'], label='train loss')
plt.plot(results.history['val_loss'], label='val loss')
plt.plot(results.history['acc'], label='train acc')
plt.plot(results.history['val_acc'], label='val acc')
plt.legend(loc='lower left')
plt.title('Power Spectral Density [1-50 Hz] MLP')
plt.xlabel('Epoch(s)')
plt.ylabel('Performance')
#plt.show()
plt.savefig(image_path+image_name, bbox_inches='tight')

# %%
"""
    Try fetching the model
"""

from keras.models import model_from_json

json_file = open(model_path+json_name)
loaded_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_json)
loaded_model.load_weights(model_path+weight_name)
loaded_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

loaded_test_score = model.evaluate(X_test, y_test)
print("\nFinal test %s: %.2f%%" % (loaded_model.metrics_names[1], loaded_test_score[1]*100))
# Out:
# 89/89 [==============================] - 0s 1ms/step
#
# Final test acc: 91.01%
